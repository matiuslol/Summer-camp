# %% [markdown]
# <a href="https://colab.research.google.com/github/matiuslol/Summer-camp/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Summer camp")
# Out:
# Summer camp

# %%
jugador = "Daisy"
print (jugador,"Ha entrado a la arena")
jugador2 = "Mario"
print(jugador2,"se ha caido de la arena")
